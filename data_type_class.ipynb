# %%
a = 'Precious'
b = 'Ojiaku'
print( a + " " + b )
# Out:
# Precious Ojiaku

# %%
1 == 1
# Out:
# True

# %%
a = 5
b = 6
c = a + b
print (c)
# Out:
# 11

# %%
c == 11
# Out:
# True

# %%
p = ('blessed', 'boo', 'eye', 'no', 'loop', 'red', 'poop')
print(p[2:7:2])
# Out:
# ('eye', 'loop', 'poop')

# %%
4>= 4
# Out:
# True

# %%
r = range(1,10)
for z in r:
    print (z)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
h = range(2,35,3)
for j in h:
    print (j)
# Out:
# 2
# 5
# 8
# 11
# 14
# 17
# 20
# 23
# 26
# 29
# 32

# %%
student_mark = {101:'frank', 102: 'bukky', 103: 'stela'}
print (student_mark)
# Out:
# {101: 'frank', 102: 'bukky', 103: 'stela'}

# %%
student_id = {101: 'frank', 102: 'bukky', 103: 'stela'}
print(student_mark[102])
# Out:
# bukky
