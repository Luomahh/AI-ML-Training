# %%
age = 21
if age <= 21:
    print("You are not ripe for marriage, young lady")
# Out:
# You are not ripe for marriage, young lady

# %%
age = 19
if age <= 21:
    print("You are not ripe for marriage, young lady")
else:
    print("when is your marriage haapening")
# Out:
# You are not ripe for marriage, young lady

# %%
if age < 13:
    print("You are in your pre-teenage years")
elif age >= 13 and age <= 19:
    print("You are in your teenage years")
elif age >= 21:
    print("You are of legal drinking age")
elif age > 18:
    print("You are a Adult")    
else:
    print("Age is not correct")
# Out:
# You are in your teenage years

# %%
score = int(input())
if score < 50:
    print("Your grade is F")
elif score >= 50 and score < 60:
    print(" Your Grade is C")
elif score >= 60 and score < 70:
    print(" Your Grade is B")    
elif score >= 70 and score <= 70:
    print(" Your Grade is A")  
else:
    print("Your have entered an invalid score")
# Out:
#  70
#  Your Grade is A

# %%
x = eval(input())
print (x*2)
# Out:
#  20.1
# 40.2

# %%
x = eval(input("Enter in a number for 'x' :" ))
y = eval(input("Enter in a number for 'y' : "))
print(x*y)
# Out:
# Enter in a number for 'x' : 19
# Enter in a number for 'y' :  10
# 190

# %%
age = eval(input("Enter the age: "))

if age == 0 and age <= 18:
    print("child")
elif age >= 18 and age <= 200:
    print("Adult")
else:
    print("Invalid age")
# Out:
# Enter the age:  12
# Invalid age

# %%
age = int(input("Enter your age: "))

if age > 0 and age < 18:
    print("child")
elif age >= 18 and age <= 200:
    print("Adult")
else:
    print("Invalid age")
# Out:
# Enter your age:  23
# Adult

# %%
#loops#

# %%
# a = "book"
for i in range(5):
    print("book")
# Out:
# book
# book
# book
# book
# book

# %%
count = 0
while count < 5:
    print(count)
    count += 1
# Out:
# 0
# 1
# 2
# 3
# 4
